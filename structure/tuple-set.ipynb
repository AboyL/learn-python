# %% [markdown]
# 元组就是不可以修改的序列，比数组或者说列表性能更好
# 集合也有不可以修改的跟可以修改的，用于去重

# %%
color = ('r', 'g', 'b', 'g', 'b', 'b') # tuple
new_color = set(color) # set
print(new_color)


new_color_2 = tuple(new_color) #tuple
print(new_color_2)

# %%
# 跟字典搭配

# dicts={{'a':1},{'b',2},{'a':1}} # error
dicts={1,2,3,2}

# 输出set个数
print(len(dicts))
# Out:
# 3
